# %% [markdown]
# # Question 1

# %%
Select customer.first_name
From customer
JOIN address
ON customer.address_id = address.address_id
WHERE address.city_id = "312";

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Question 2

# %%
SELECT title, description, release_year, rating, special_features
FROM film as f
	JOIN film_category as fc
	ON f.film_id = fc.film_id
	LEFT JOIN category as c
	ON fc.category_id = c.category_id
	WHERE c.category_id = 5

# %% [markdown]
# ![Screenshot%202023-04-27%20235201.png](attachment:Screenshot%202023-04-27%20235201.png)

# %% [markdown]
# # Question 3

# %%
SELECT last_name, title, release_year
FROM film as f
	JOIN film_actor as fa
	ON f.film_id = fa.film_id
	LEFT JOIN actor as a
	ON fa.actor_id = a.actor_id
	WHERE a.actor_id = 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Question 4

# %%
SELECT first_name, last_name
FROM actor as a
	JOIN film_actor as fa
	ON a.actor_id = fa.actor_id
	LEFT JOIN film as f
	ON fa.film_id = f.film_id
	WHERE f.title = "Bingo Talented"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Question 5

# %%
SELECT customer_id, amount
FROM payment
WHERE amount >
	(SELECT AVG(amount)
    FROM payment);

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Question 6

# %%
SELECT customer.first_name, customer.last_name,
	(SELECT COUNT(*)
    From payment
    WHERE customer.customer_id = payment.customer_id) AS num_payments
FROM customer
ORDER by num_payments DESC
LIMIT 5;

# %% [markdown]
# ![image.png](attachment:image.png)
